# %% [markdown]
# Escolher uma API da lista disponível;
# Fazer a extração de pelo menos 3 tabelas;
# Criar um alerta de erro usando a função alerta() do desafio da aula
#
# APIs disponíveis:
# Brasil API - https://brasilapi.com.br/docs
# Rest Coutries - https://restcountries.com/
# PokéAPI - https://pokeapi.co/
# Open Weather Map - https://openweathermap.org/ap

# %%
from datetime import datetime
from plyer import notification

def alerta(nivel, base, etapa):
    '''
        Alerta de falha de carregamento de base de dados
    '''
    now = str(datetime.now())

    msg = f"Falha no carregamento da base {base} na etapa {etapa}.\n{now}"


    if nivel == 1:
        title = 'ATENÇÃO: Alerta Baixo'
    elif nivel == 2:
        title = 'ATENÇÃO: Alerta Médio'
    elif nivel  == 3:
        title = 'ATENÇÃO: Alerta Alto'
    else:
        print("Nivel",nivel,"não disponível!")

    notification.notify(
            title=title,
            message=msg,
            app_name='alerta',
            timeout=10
        )

# %%
import pandas as pd
import requests

url1 = "https://brasilapi.com.br/api/cptec/v1/cidade"
url2 = "https://brasilapi.com.br/api/cptec/v1/clima/capital"
url3 = "https://brasilapi.com.br/api/cptec/v1/clima/previsao/{cityCode}"

# Função para permitir a extração dos dados e geração da tabela (será incrementado posteriormente o retorno para permitir as manipulações)
def carregar_dados(url):
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        df = pd.DataFrame(data)
        print(df)
    else:
        data = []
        alerta(nivel = 2,
            base = f"API " + url,
            etapa = f"Falha na requisição. Código de status: " + str(response.status_code))
        

        
carregar_dados(url1)
carregar_dados(url2)
carregar_dados(url3)
# Out:
#                          nome    id estado
# 0                São Benedito  4750     CE
# 1   São Benedito do Rio Preto  4751     MA
# 2         São Benedito do Sul  4752     PE
# 3                   São Bento  4753     MA
# 4                   São Bento  4754     PB
# 5             São Bento Abade  4755     MG
# 6         São Bento de Pombal  4756     PB
# 7          São Bento do Norte  4757     RN
# 8        São Bento do Sapucaí  4758     SP
# 9            São Bento do Sul  4759     SC
# 10     São Bento do Tocantins  4760     TO
# 11        São Bento do Trairi  4761     RN
# 12           São Bento do Una  4762     PE
# 13             São Bernardino  4763     SC
# 14               São Bernardo  4764     MA
# 15      São Bernardo do Campo  4765     SP
# 16              São Bonifácio  4766     SC
# 17                  São Borja  4767     RS
# 18                   São Brás  4768     AL
# 19         São Brás do Suaçuí  4769     MG
# 20          São Braz do Piauí  4770     PI
# ...
